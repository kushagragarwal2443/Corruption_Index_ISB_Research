# %%
import pandas as pd

# %%
data = pd.read_csv("../The_hindu_scrapped/y_1819_Scored.csv")

# %%
len(data)
# Out:
# 59146

# %%
data1 = data[data["Score"]>0]
len(data1)
# Out:
# 4865

# %%
data2 = data[data["Score"]>1.5]
len(data2)
# Out:
# 1256

# %%
data3 = data[data["Score"]>1.75]
len(data3)
# Out:
# 1003

# %%
# Percentage of samples with score >1.5
len(data2)/len(data1) * 100
# Out:
# 25.81706063720452

# %%
# Percentage of samples with score >1.75
len(data3)/len(data1) * 100
# Out:
# 20.616649537512846

# %%
for j in range(9,11):
    strin="../The_hindu_scrapped/y_"+str(j)+"_Scored.csv"
    data = pd.read_csv(strin)
    data1 = data[data["Score"]>0]
    x=[]
    
    # Creates histogram to count number of articles with scores in the buckets 0 to 1.5 with a bucker size of 0.1
    for i in range(1,51,1):
        datax= data[data["Score"]<=(i/10)]
        datax= datax[datax["Score"]>(i/10-0.1)]
        length = len(datax)
        x.append(length/len(data1))

    perclist=[]
    for i in range(5, 505, 10):
        perclist.append(str(i/100))
    print(str(2000+j))
    plt.figure(figsize=(25,10))
    plt.bar(perclist, x)
    plt.show()
# Out:
# 2009
# 2010

# %%
yearly_percentile = [23.93980848153215, 31.60978094752929, 38.61796271888534, 28.71432056599171, 28.772635814889334, 27.207283506246032, 17.735849056603772, 30.685203574975173, 30.390021777865766, 25.81706063720452]

# %%
print(len(yearly_percentile))
sumpercent=0
for i in range(len(yearly_percentile)):
    sumpercent+=yearly_percentile[i]
sumlist=[]
for i in range(len(yearly_percentile)):
    sumlist.append(sumpercent/len(yearly_percentile))
sumpercent/len(yearly_percentile)
# Out:
# 10
# 28.348992708172307

# %%
import matplotlib.pyplot as plt

# %%
year_list=[]
for i in range(9,19):
    year_list.append(str(i))

# %%
plt.plot(year_list, yearly_percentile)
plt.plot(year_list, sumlist)
plt.show()
